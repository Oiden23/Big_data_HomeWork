# %% [markdown]
# # ДОМАШНЕЕ ЗАДАНИЕ 4. Рекомендательные системы и Spark MLlib

# %% [markdown]
# **Дисциплина:** Методы обработки больших данных
# **Студент:** Попов Я.Ю.
# **Группа:** ИУ6-31М

# %% [markdown]
# ## Решение для полного набора данных

# %% [markdown]
# ### Задание 1. Анализ датасета

# %% [markdown]
# 1. Выведите данные, сопоставляющие жанры и количество фильмов
# 2. Выведите первые 10 фильмов с наибольшим количеством рейтингов для каждого жанра в соответствии с вариантом
# 3. Выведите первые 10 фильмов с наименьшим количеством рейтингов (но больше 10) для каждого жанра в соответствии с вариантом
# 4. Выведите первые 10 фильмов с наибольшим средним рейтингом при количестве рейтингов больше 10 для каждого жанра в соответствии с вариантом
# 5. Выведите первые 10 фильмов с наименьшим средним рейтингом при количестве рейтингов больше 10 для каждого жанра в соответствии с вариантом

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, explode, split, count, avg, row_number
from pyspark.sql.window import Window

# Инициализация SparkSession
spark = SparkSession.builder \
    .appName("MovieRecommendationAnalysis") \
    .getOrCreate()

# Загрузка данных
movies_df = spark.read.csv("movies.csv", header=True, inferSchema=True)
ratings_df = spark.read.csv("ratings.csv", header=True, inferSchema=True)

# Список требуемых жанров
genres = [
    "Animation", "Romance", "Documentary", "Drama", 
    "Comedy", "Musical", "Thriller", "Sci-Fi", "Adventure"
]
# Out:
# /home/ubuntu/ML/anaconda3/lib/python3.7/site-packages/pyspark/context.py:317: FutureWarning: Python 3.7 support is deprecated in Spark 3.4.
#   warnings.warn("Python 3.7 support is deprecated in Spark 3.4.", FutureWarning)

# %% [markdown]
# ## Задача 1: Количество фильмов по жанрам

# %%
# Разделение на жанры по "|"
movies_exploded = movies_df.withColumn("genre", explode(split(col("genres"), "\\|")))
genre_counts = (
    movies_exploded
    .filter(col("genre").isin(genres))
    .groupBy("genre")
    .count()
    .orderBy(col("count").desc())
)

print("Задача 1: Количество фильмов по жанрам")
genre_counts.show()
# Out:
# Задача 1: Количество фильмов по жанрам
# +-----------+-----+
# |      genre|count|
# +-----------+-----+
# |      Drama|33681|
# |     Comedy|22829|
# |   Thriller|11675|
# |    Romance|10172|
# |Documentary| 9283|
# |  Adventure| 5349|
# |     Sci-Fi| 4850|
# |  Animation| 4579|
# |    Musical| 1059|
# +-----------+-----+

# %% [markdown]
# ## Задача 2: Топ-10 фильмов с наибольшим количеством рейтингов для каждого жанра

# %%
# Агрегация рейтингов
movie_ratings = (
    ratings_df
    .groupBy("movieId")
    .agg(
        count("rating").alias("rating_count"),
        avg("rating").alias("avg_rating")
    )
)

# Объединение с информацией о фильмах
movies_enriched = (
    movies_df
    .join(movie_ratings, "movieId", "inner")
    .withColumn("genre", explode(split(col("genres"), "\\|")))
    .filter(col("genre").isin(genres))
)


window_desc = Window.partitionBy("genre").orderBy(col("rating_count").desc())
top_by_count = (
    movies_enriched
    .withColumn("rank", row_number().over(window_desc))
    .filter(col("rank") <= 10)
    .select("genre", "title", "rating_count", "rank")
    .orderBy("genre", "rank")
)

print("\nЗадача 2: Топ-10 по количеству рейтингов")
top_by_count.show(n=100, truncate=False)
# Out:
# Задача 2: Топ-10 по количеству рейтингов
# +-----------+------------------------------------------------------------------------------+------------+----+
# |genre      |title                                                                         |rating_count|rank|
# +-----------+------------------------------------------------------------------------------+------------+----+
# |Adventure  |Star Wars: Episode IV - A New Hope (1977)                                     |97202       |1   |
# |Adventure  |Jurassic Park (1993)                                                          |83026       |2   |
# |Adventure  |Star Wars: Episode V - The Empire Strikes Back (1980)                         |80200       |3   |
# |Adventure  |Lord of the Rings: The Fellowship of the Ring, The (2001)                     |79940       |4   |
# |Adventure  |Toy Story (1995)                                                              |76813       |5   |
# |Adventure  |Star Wars: Episode VI - Return of the Jedi (1983)                             |76773       |6   |
# |Adventure  |Lord of the Rings: The Return of the King, The (2003)                         |75512       |7   |
# |Adventure  |Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)|75248       |8   |
# |Adventure  |Lord of the Rings: The Two Towers, The (2002)                                 |73687       |9   |
# |Adventure  |Back to the Future (1985)                                                     |67777       |10  |
# |Animation  |Toy Story (1995)                                                              |76813       |1   |
# |Animation  |Shrek (2001)                                                                  |58529       |2   |
# |Animation  |Aladdin (1992)                                                                |55791       |3   |
# |Animation  |Lion King, The (1994)                                                         |53509       |4   |
# |Animation  |Monsters, Inc. (2001)                                                         |48441       |5   |
# |Animation  |Finding Nemo (2003)                                                           |48124       |6   |
# |Animation  |Beauty and the Beast (1991)                                                   |45404       |7   |
# |Animation  |Incredibles, The (2004)                                                       |42953       |8   |
# |Animation  |WALL·E (2008)                                                                 |42033       |9   |
# |Animation  |Up (2009)                                                                     |38751       |10  |
# |Comedy     |Forrest Gump (1994)                                                           |113581      |1   |
# |Comedy     |Pulp Fiction (1994)                                                           |108756      |2   |
# |Comedy     |Toy Story (1995)                                                              |76813       |3   |
# |Comedy     |Back to the Future (1985)                                                     |67777       |4   |
# |Comedy     |Fargo (1996)                                                                  |61977       |5   |
# |Comedy     |Shrek (2001)                                                                  |58529       |6   |
# |Comedy     |Aladdin (1992)                                                                |55791       |7   |
# |Comedy     |True Lies (1994)                                                              |52789       |8   |
# |Comedy     |Pirates of the Caribbean: The Curse of the Black Pearl (2003)                 |50868       |9   |
# |Comedy     |Princess Bride, The (1987)                                                    |50775       |10  |
# |Documentary|Bowling for Columbine (2002)                                                  |16608       |1   |
# |Documentary|Super Size Me (2004)                                                          |14077       |2   |
# |Documentary|Hoop Dreams (1994)                                                            |11731       |3   |
# |Documentary|Fahrenheit 9/11 (2004)                                                        |11553       |4   |
# |Documentary|Roger & Me (1989)                                                             |8296        |5   |
# |Documentary|Crumb (1994)                                                                  |6758        |6   |
# |Documentary|Jackass: The Movie (2002)                                                     |5685        |7   |
# |Documentary|March of the Penguins (Marche de l'empereur, La) (2005)                       |4542        |8   |
# |Documentary|When We Were Kings (1996)                                                     |4207        |9   |
# |Documentary|Inconvenient Truth, An (2006)                                                 |4168        |10  |
# |Drama      |Shawshank Redemption, The (1994)                                              |122296      |1   |
# |Drama      |Forrest Gump (1994)                                                           |113581      |2   |
# |Drama      |Pulp Fiction (1994)                                                           |108756      |3   |
# |Drama      |Fight Club (1999)                                                             |86207       |4   |
# |Drama      |Schindler's List (1993)                                                       |84232       |5   |
# |Drama      |Braveheart (1995)                                                             |75514       |6   |
# |Drama      |Lord of the Rings: The Return of the King, The (2003)                         |75512       |7   |
# |Drama      |Godfather, The (1972)                                                         |75004       |8   |
# |Drama      |American Beauty (1999)                                                        |69902       |9   |
# |Drama      |Dark Knight, The (2008)                                                       |65349       |10  |
# |Musical    |Aladdin (1992)                                                                |55791       |1   |
# |Musical    |Lion King, The (1994)                                                         |53509       |2   |
# |Musical    |Beauty and the Beast (1991)                                                   |45404       |3   |
# |Musical    |Willy Wonka & the Chocolate Factory (1971)                                    |35707       |4   |
# |Musical    |Wizard of Oz, The (1939)                                                      |30354       |5   |
# |Musical    |Shrek 2 (2004)                                                                |26972       |6   |
# |Musical    |Nightmare Before Christmas, The (1993)                                        |26830       |7   |
# |Musical    |Blues Brothers, The (1980)                                                    |25280       |8   |
# |Musical    |South Park: Bigger, Longer and Uncut (1999)                                   |22130       |9   |
# |Musical    |Snow White and the Seven Dwarfs (1937)                                        |21907       |10  |
# |Romance    |Forrest Gump (1994)                                                           |113581      |1   |
# |Romance    |American Beauty (1999)                                                        |69902       |2   |
# |Romance    |Shrek (2001)                                                                  |58529       |3   |
# |Romance    |Good Will Hunting (1997)                                                      |54980       |4   |
# |Romance    |True Lies (1994)                                                              |52789       |5   |
# |Romance    |Princess Bride, The (1987)                                                    |50775       |6   |
# |Romance    |Titanic (1997)                                                                |50706       |7   |
# |Romance    |Speed (1994)                                                                  |49029       |8   |
# |Romance    |Groundhog Day (1993)                                                          |47956       |9   |
# |Romance    |Eternal Sunshine of the Spotless Mind (2004)                                  |46292       |10  |
# |Sci-Fi     |Matrix, The (1999)                                                            |107056      |1   |
# |Sci-Fi     |Star Wars: Episode IV - A New Hope (1977)                                     |97202       |2   |
# |Sci-Fi     |Jurassic Park (1993)                                                          |83026       |3   |
# |Sci-Fi     |Star Wars: Episode V - The Empire Strikes Back (1980)                         |80200       |4   |
# |Sci-Fi     |Star Wars: Episode VI - Return of the Jedi (1983)                             |76773       |5   |
# |Sci-Fi     |Terminator 2: Judgment Day (1991)                                             |71820       |6   |
# |Sci-Fi     |Back to the Future (1985)                                                     |67777       |7   |
# |Sci-Fi     |Inception (2010)                                                              |65056       |8   |
# |Sci-Fi     |Independence Day (a.k.a. ID4) (1996)                                          |63687       |9   |
# |Sci-Fi     |Twelve Monkeys (a.k.a. 12 Monkeys) (1995)                                     |59730       |10  |
# |Thriller   |Pulp Fiction (1994)                                                           |108756      |1   |
# |Thriller   |Matrix, The (1999)                                                            |107056      |2   |
# |Thriller   |Silence of the Lambs, The (1991)                                              |101802      |3   |
# |Thriller   |Fight Club (1999)                                                             |86207       |4   |
# |Thriller   |Jurassic Park (1993)                                                          |83026       |5   |
# |Thriller   |Usual Suspects, The (1995)                                                    |72893       |6   |
# |Thriller   |Seven (a.k.a. Se7en) (1995)                                                   |65666       |7   |
# |Thriller   |Inception (2010)                                                              |65056       |8   |
# |Thriller   |Independence Day (a.k.a. ID4) (1996)                                          |63687       |9   |
# |Thriller   |Fargo (1996)                                                                  |61977       |10  |
# +-----------+------------------------------------------------------------------------------+------------+----+

# %% [markdown]
# ## Задача 3: Топ-10 фильмов с наименьшим количеством рейтингов (>10) для каждого жанра

# %%
window_asc = Window.partitionBy("genre").orderBy(col("rating_count").asc())
filtered_movies = movies_enriched.filter(col("rating_count") > 10)
bottom_by_count = (
    filtered_movies
    .withColumn("rank", row_number().over(window_asc))
    .filter(col("rank") <= 10)
    .select("genre", "title", "rating_count", "rank")
    .orderBy("genre", "rank")
)
print("\nЗадача 3: Наименьшее количество рейтингов (>10)")
bottom_by_count.show(truncate=False)
# Out:
# Задача 3: Наименьшее количество рейтингов (>10)
# +---------+------------------------------------------------------+------------+----+
# |genre    |title                                                 |rating_count|rank|
# +---------+------------------------------------------------------+------------+----+
# |Adventure|Edge of the World (2021)                              |11          |1   |
# |Adventure|Righteous Ties (2006)                                 |11          |2   |
# |Adventure|A Tourist's Guide to Love (2023)                      |11          |3   |
# |Adventure|Frontier (2018)                                       |11          |4   |
# |Adventure|The Life and Death of a Porno Gang (2009)             |11          |5   |
# |Adventure|Blackie the Pirate (1971)                             |11          |6   |
# |Adventure|To Kill a King (2003)                                 |11          |7   |
# |Adventure|K2: Siren of the Himalayas (2012)                     |11          |8   |
# |Adventure|Journey to the Center of the Earth (1999)             |11          |9   |
# |Adventure|Five Weeks in a Balloon (1962)                        |11          |10  |
# |Animation|The Heron and the Crane (1974)                        |11          |1   |
# |Animation|Sturgill Simpson Presents Sound & Fury (2019)         |11          |2   |
# |Animation|Szaffi (1985)                                         |11          |3   |
# |Animation|Mickey's Polo Team (1936)                             |11          |4   |
# |Animation|The Tangerine Bear: Home in Time for Christmas! (2000)|11          |5   |
# |Animation|Chunin Exam on Fire! and Naruto vs. Konohamaru! (2004)|11          |6   |
# |Animation|DC Showcase: Sgt. Rock (2019)                         |11          |7   |
# |Animation|ON-GAKU: Our Sound (2020)                             |11          |8   |
# |Animation|Bayonetta: Bloody Fate (2013)                         |11          |9   |
# |Animation|The Lion, the Witch and the Wardrobe (1979)           |11          |10  |
# +---------+------------------------------------------------------+------------+----+
# only showing top 20 rows

# %% [markdown]
# ## Задача 4: Топ-10 фильмов с наибольшим средним рейтингом (>10 рейтингов)

# %%
window_avg_desc = Window.partitionBy("genre").orderBy(
    col("avg_rating").desc(),
    col("rating_count").desc()
)
top_by_avg = (
    filtered_movies
    .withColumn("rank", row_number().over(window_avg_desc))
    .filter(col("rank") <= 10)
    .select("genre", "title", "avg_rating", "rating_count", "rank")
    .orderBy("genre", "rank")
)
print("\nЗадача 4: Наивысший средний рейтинг (>10)")
top_by_avg.show(truncate=False)
# Out:
# Задача 4: Наивысший средний рейтинг (>10)
# +---------+----------------------------------------------------+------------------+------------+----+
# |genre    |title                                               |avg_rating        |rating_count|rank|
# +---------+----------------------------------------------------+------------------+------------+----+
# |Adventure|Over the Garden Wall (2013)                         |4.256993006993007 |1430        |1   |
# |Adventure|Spider-Man: Across the Spider-Verse (2023)          |4.252840909090909 |528         |2   |
# |Adventure|Seven Samurai (Shichinin no samurai) (1954)         |4.2508177570093455|17120       |3   |
# |Adventure|Adventure Time: Elements (2017)                     |4.25              |12          |4   |
# |Adventure|Spirited Away (Sen to Chihiro no kamikakushi) (2001)|4.226035335689046 |35375       |5   |
# |Adventure|Spider-Man: Into the Spider-Verse (2018)            |4.192053284336242 |10885       |6   |
# |Adventure|North by Northwest (1959)                           |4.187337202394553 |21883       |7   |
# |Adventure|City of God (Cidade de Deus) (2002)                 |4.1835973391157335|27209       |8   |
# |Adventure|Firefly (2002)                                      |4.174301675977653 |895         |9   |
# |Adventure|Yojimbo (1961)                                      |4.167050691244239 |5208        |10  |
# |Animation|Over the Garden Wall (2013)                         |4.256993006993007 |1430        |1   |
# |Animation|Spider-Man: Across the Spider-Verse (2023)          |4.252840909090909 |528         |2   |
# |Animation|Adventure Time: Elements (2017)                     |4.25              |12          |3   |
# |Animation|Spirited Away (Sen to Chihiro no kamikakushi) (2001)|4.226035335689046 |35375       |4   |
# |Animation|Violet Evergarden: The Movie (2020)                 |4.22              |25          |5   |
# |Animation|It's Such a Beautiful Day (2011)                    |4.1935975609756095|328         |6   |
# |Animation|Spider-Man: Into the Spider-Verse (2018)            |4.192053284336242 |10885       |7   |
# |Animation|Your Name. (2016)                                   |4.16751269035533  |3940        |8   |
# |Animation|Princess Mononoke (Mononoke-hime) (1997)            |4.166026555470207 |18226       |9   |
# |Animation|My Neighbor Totoro (Tonari no Totoro) (1988)        |4.163490364025696 |14010       |10  |
# +---------+----------------------------------------------------+------------------+------------+----+
# only showing top 20 rows

# %% [markdown]
# ## Задача 5: Топ-10 фильмов с наименьшим средним рейтингом (>10 рейтингов)

# %%
window_avg_asc = Window.partitionBy("genre").orderBy(
    col("avg_rating").asc(),
    col("rating_count").desc()
)
bottom_by_avg = (
    filtered_movies
    .withColumn("rank", row_number().over(window_avg_asc))
    .filter(col("rank") <= 10)
    .select("genre", "title", "avg_rating", "rating_count", "rank")
    .orderBy("genre", "rank")
)
print("\nЗадача 5: Наименьший средний рейтинг (>10)")
bottom_by_avg.show(n=100, truncate=False)
# Out:
# Задача 5: Наименьший средний рейтинг (>10)
# +-----------+------------------------------------------------------------------------+------------------+------------+----+
# |genre      |title                                                                   |avg_rating        |rating_count|rank|
# +-----------+------------------------------------------------------------------------+------------------+------------+----+
# |Adventure  |Kidnapping, Caucasian Style (2014)                                      |0.9117647058823529|17          |1   |
# |Adventure  |Titanic 2 (2010)                                                        |1.0454545454545454|22          |2   |
# |Adventure  |Bigfoot (2012)                                                          |1.0588235294117647|17          |3   |
# |Adventure  |Beethoven's Treasure Tail (2014)                                        |1.1666666666666667|15          |4   |
# |Adventure  |Barney's Great Adventure (1998)                                         |1.2343412526997841|463         |5   |
# |Adventure  |Son of the Mask (2005)                                                  |1.2414403778040142|847         |6   |
# |Adventure  |Transmorphers (2007)                                                    |1.25              |22          |7   |
# |Adventure  |Cool Cat Saves the Kids (2015)                                          |1.2903225806451613|31          |8   |
# |Adventure  |Mega Piranha (2010)                                                     |1.3928571428571428|28          |9   |
# |Adventure  |The Star Wars Holiday Special (1978)                                    |1.3991935483870968|248         |10  |
# |Animation  |Foodfight! (2012)                                                       |0.9456521739130435|46          |1   |
# |Animation  |The Swan Princess Christmas (2012)                                      |1.1363636363636365|11          |2   |
# |Animation  |The Amazing Bulk (2012)                                                 |1.1666666666666667|15          |3   |
# |Animation  |Barbie & Her Sisters in the Great Puppy Adventure (2015)                |1.1923076923076923|78          |4   |
# |Animation  |Norm of the North (2016)                                                |1.5086206896551724|58          |5   |
# |Animation  |Pokémon Heroes (2003)                                                   |1.519721577726218 |431         |6   |
# |Animation  |Pokemon 4 Ever (a.k.a. Pokémon 4: The Movie) (2002)                     |1.5358306188925082|614         |7   |
# |Animation  |Maya the Bee Movie (2014)                                               |1.5833333333333333|12          |8   |
# |Animation  |Norm of the North: Keys to the Kingdom (2018)                           |1.5909090909090908|11          |9   |
# |Animation  |The Legend of the Titanic (1999)                                        |1.6363636363636365|11          |10  |
# |Comedy     |Kartoffelsalat - Nicht Fragen! (2015)                                   |0.8181818181818182|11          |1   |
# |Comedy     |Hip Hop Witch, Da (2000)                                                |0.8548387096774194|31          |2   |
# |Comedy     |Saving Christmas (2014)                                                 |0.8611111111111112|36          |3   |
# |Comedy     |SuperBabies: Baby Geniuses 2 (2004)                                     |0.8796992481203008|266         |4   |
# |Comedy     |Kidnapping, Caucasian Style (2014)                                      |0.9117647058823529|17          |5   |
# |Comedy     |Beethoven's Christmas Adventure (2011)                                  |0.9333333333333333|15          |6   |
# |Comedy     |Foodfight! (2012)                                                       |0.9456521739130435|46          |7   |
# |Comedy     |Dzhentlmeny, Udachi! (2012)                                             |1.0625            |16          |8   |
# |Comedy     |The Amazing Bulk (2012)                                                 |1.1666666666666667|15          |9   |
# |Comedy     |Pledge This! (2006)                                                     |1.1896551724137931|29          |10  |
# |Documentary|Justin Bieber's Believe (2013)                                          |0.9285714285714286|21          |1   |
# |Documentary|Death of a Nation (2018)                                                |1.2142857142857142|14          |2   |
# |Documentary|Faces of Death 6 (1996)                                                 |1.2865168539325842|178         |3   |
# |Documentary|Justin Bieber: Never Say Never (2011)                                   |1.2936507936507937|63          |4   |
# |Documentary|Faces of Death 5 (1996)                                                 |1.365625          |160         |5   |
# |Documentary|Faces of Death: Fact or Fiction? (1999)                                 |1.3759398496240602|133         |6   |
# |Documentary|Kony 2012 (2012)                                                        |1.3846153846153846|13          |7   |
# |Documentary|Faces of Death 4 (1990)                                                 |1.3945945945945946|185         |8   |
# |Documentary|Faces of Death 3 (1985)                                                 |1.4951690821256038|207         |9   |
# |Documentary|Electrocuting an Elephant (1903)                                        |1.53125           |32          |10  |
# |Drama      |Crimea (2017)                                                           |0.92              |25          |1   |
# |Drama      |Music (2020)                                                            |1.0714285714285714|21          |2   |
# |Drama      |Glitter (2001)                                                          |1.151015228426396 |788         |3   |
# |Drama      |The Trump Prophecy (2018)                                               |1.1666666666666667|12          |4   |
# |Drama      |Tubelight (2017)                                                        |1.2105263157894737|19          |5   |
# |Drama      |Daniel, the Wizard (2004)                                               |1.2142857142857142|14          |6   |
# |Drama      |Black Rose (2014)                                                       |1.2692307692307692|13          |7   |
# |Drama      |Final Justice (1985)                                                    |1.3181818181818181|11          |8   |
# |Drama      |Loqueesha (2019)                                                        |1.3461538461538463|13          |9   |
# |Drama      |Farewell, The (Abschied - Brechts letzter Sommer) (2000)                |1.368421052631579 |19          |10  |
# |Musical    |From Justin to Kelly (2003)                                             |1.0112474437627812|489         |1   |
# |Musical    |Glitter (2001)                                                          |1.151015228426396 |788         |2   |
# |Musical    |Drona (2008)                                                            |1.5               |11          |3   |
# |Musical    |Elstree Calling (1930)                                                  |1.625             |12          |4   |
# |Musical    |Dance Flick (2009)                                                      |1.645631067961165 |103         |5   |
# |Musical    |Love Story 2050 (2008)                                                  |1.72              |25          |6   |
# |Musical    |Creature Wasn't Nice, The (a.k.a. Naked Space) (a.k.a. Spaceship) (1981)|1.7222222222222223|36          |7   |
# |Musical    |Roadie (1980)                                                           |1.8636363636363635|33          |8   |
# |Musical    |Kambakkht Ishq (Incredible Love) (2009)                                 |1.8846153846153846|39          |9   |
# |Musical    |Crossroads (2002)                                                       |1.914516129032258 |1240        |10  |
# |Romance    |Kidnapping, Caucasian Style (2014)                                      |0.9117647058823529|17          |1   |
# |Romance    |From Justin to Kelly (2003)                                             |1.0112474437627812|489         |2   |
# |Romance    |Glitter (2001)                                                          |1.151015228426396 |788         |3   |
# |Romance    |Gigli (2003)                                                            |1.2144495412844036|872         |4   |
# |Romance    |Wedding Trough (Vase de noces) (1975)                                   |1.4333333333333333|15          |5   |
# |Romance    |Forever (2015)                                                          |1.5               |14          |6   |
# |Romance    |Classmates (2016)                                                       |1.5               |11          |7   |
# |Romance    |Tashan (2008)                                                           |1.5454545454545454|11          |8   |
# |Romance    |Shanghai Surprise (1986)                                                |1.5637450199203187|251         |9   |
# |Romance    |Date Movie (2006)                                                       |1.6176991150442477|1130        |10  |
# |Sci-Fi     |6-Headed Shark Attack (2018)                                            |0.9074074074074074|27          |1   |
# |Sci-Fi     |A Nymphoid Barbarian in Dinosaur Hell (1990)                            |0.9333333333333333|15          |2   |
# |Sci-Fi     |Bigfoot (2012)                                                          |1.0588235294117647|17          |3   |
# |Sci-Fi     |AVH: Alien vs. Hunter (2007)                                            |1.2142857142857142|14          |4   |
# |Sci-Fi     |Transmorphers (2007)                                                    |1.25              |22          |5   |
# |Sci-Fi     |51 (2011)                                                               |1.3214285714285714|14          |6   |
# |Sci-Fi     |Future War (1997)                                                       |1.3636363636363635|11          |7   |
# |Sci-Fi     |Atlantic Rim (2013)                                                     |1.3653846153846154|26          |8   |
# |Sci-Fi     |Carnosaur 3: Primal Species (1996)                                      |1.367741935483871 |155         |9   |
# |Sci-Fi     |Mega Piranha (2010)                                                     |1.3928571428571428|28          |10  |
# |Thriller   |Hip Hop Witch, Da (2000)                                                |0.8548387096774194|31          |1   |
# |Thriller   |Titanic 2 (2010)                                                        |1.0454545454545454|22          |2   |
# |Thriller   |Mrs. Serial Killer (2020)                                               |1.3333333333333333|12          |3   |
# |Thriller   |Discarnate (2019)                                                       |1.375             |12          |4   |
# |Thriller   |The Legend of La Llorona (2020)                                         |1.4375            |16          |5   |
# |Thriller   |The Attic (2008)                                                        |1.4583333333333333|12          |6   |
# |Thriller   |Alone in the Dark (2005)                                                |1.4975961538461537|624         |7   |
# |Thriller   |Anaconda: The Offspring (2008)                                          |1.5               |55          |8   |
# |Thriller   |Forever (2015)                                                          |1.5               |14          |9   |
# |Thriller   |River Runs Red (2018)                                                   |1.5               |12          |10  |
# +-----------+------------------------------------------------------------------------+------------------+------------+----+

# %% [markdown]
# ## Остановка SparkSession

# %%
spark.stop()

# %% [markdown]
# ## Задание 2. Коллаборативная фильтрация

# %% [markdown]
# Вариант 1. По схожести пользователей
#
# Вариант 2. По схожести объектов
#
# 1. Разделите данные с рейтингами на обучающее (train_init - 0.8) и тестовое подмножества (test - 0.2), определите среднее значение рейтинга в обучающем подмножестве и вычислите rmse для тестового подмножества, если для всех значений из test предсказывается среднее значение рейтинга
# 2. Реализуйте коллаборативную фильтрацию в соответствии с вариантом. Для определения схожести используйте train_init, для расчета rmse - test
# 3. Определите rmse для тестового подмножества

# %%
surname = "Попов" 

alp = 'абвгдеёжзийклмнопрстуфхцчшщъыьэюя'
w = [1, 42, 21, 21, 34,  6, 44, 26, 18, 44, 38, 26, 14, 43,  4, 49, 45,
        7, 42, 29,  4,  9, 36, 34, 31, 29,  5, 30,  4, 19, 28, 25, 33]

d = dict(zip(alp, w))
variant =  sum([d[el] for el in surname.lower()]) % 40 + 1

print("Задача № 2: ", variant % 2 + 1 )
# Out:
# Задача № 2:  1

# %% [markdown]
# ## Инициализация SparkSession

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, lit, avg, sqrt, broadcast
from pyspark.ml.recommendation import ALS
from pyspark.ml.evaluation import RegressionEvaluator
import time

# Инициализация SparkSession для работы с полным набором данных
spark = SparkSession.builder \
    .appName("MovieLens_FullDataset_Analysis") \
    .config("spark.driver.memory", "8g") \
    .config("spark.executor.memory", "8g") \
    .config("spark.sql.shuffle.partitions", "200") \
    .config("spark.default.parallelism", "200") \
    .config("spark.driver.maxResultSize", "4g") \
    .config("spark.memory.fraction", "0.8") \
    .getOrCreate()

ratings_df = spark.read.csv("ratings.csv", header=True, inferSchema=True)

# Кэширование данных для ускорения обработки
ratings_df = ratings_df.cache()
# Out:
# /home/ubuntu/ML/anaconda3/lib/python3.7/site-packages/pyspark/context.py:317: FutureWarning: Python 3.7 support is deprecated in Spark 3.4.
#   warnings.warn("Python 3.7 support is deprecated in Spark 3.4.", FutureWarning)

# %% [markdown]
# ## 1: Разделение данных и вычисление RMSE для среднего значения

# %%
# Разделение данных
train_init, test = ratings_df.randomSplit([0.8, 0.2], seed=42)

# Вычисление среднего рейтинга в обучающей выборке
start_time = time.time()
avg_rating = train_init.agg(avg("rating").alias("avg_rating")).collect()[0]["avg_rating"]
print(f"Средний рейтинг в обучающей выборке: {avg_rating:.4f}")
print(f"Вычислено за {time.time() - start_time:.2f} секунд")

# Создание предсказаний для тестового набора
test_with_pred = test.withColumn("prediction", lit(avg_rating))

# Расчет RMSE вручную
start_time = time.time()
rmse_base = test_with_pred.withColumn("squared_error", (col("rating") - col("prediction")) ** 2)
rmse_base = rmse_base.agg(sqrt(avg("squared_error")).alias("rmse")).collect()[0]["rmse"]
print(f"RMSE базовой модели (предсказание средним): {rmse_base:.4f}")
print(f"RMSE рассчитано за {time.time() - start_time:.2f} секунд")
# Out:
# Средний рейтинг в обучающей выборке: 3.5426
# Вычислено за 34.94 секунд
# RMSE базовой модели (предсказание средним): 1.0641
# RMSE рассчитано за 4.14 секунд

# %% [markdown]
# ## 2: Реализация коллаборативной фильтрации по схожести пользователей

# %%
# Подготовка данных для ALS
als_train = train_init.select(
    col("userId").cast("integer").alias("user"),
    col("movieId").cast("integer").alias("item"),
    col("rating").cast("float")
).cache()

als_test = test.select(
    col("userId").cast("integer").alias("user"),
    col("movieId").cast("integer").alias("item"),
    col("rating").cast("float")
).cache()

# Настройка параметров ALS 
als = ALS(
    maxIter=15,
    regParam=0.1,
    rank=10,
    userCol="user",
    itemCol="item",
    ratingCol="rating",
    coldStartStrategy="drop",
    nonnegative=True,
    seed=42
)

# Обучение ALS модели
start_time = time.time()
model = als.fit(als_train)
training_time = time.time() - start_time
print(f"Модель обучена за {training_time:.2f} секунд")

# Предсказание рейтинов для тестового набора
start_time = time.time()
predictions = model.transform(als_test)
prediction_time = time.time() - start_time
print(f"Предсказания сгенерированы за {prediction_time:.2f} секунд")
# Out:
# Модель обучена за 125.95 секунд
# Предсказания сгенерированы за 0.25 секунд

# %% [markdown]
# ## 3: Определение RMSE для тестового подмножества

# %%
# Расчет RMSE
start_time = time.time()
evaluator = RegressionEvaluator(
    metricName="rmse",
    labelCol="rating",
    predictionCol="prediction"
)

rmse_als = evaluator.evaluate(predictions)
print(f"RMSE ALS модели: {rmse_als:.4f}")

# Альтернативный расчет RMSE вручную для валидации
rmse_manual = predictions.withColumn("squared_error", (col("rating") - col("prediction")) ** 2)
rmse_manual = rmse_manual.agg(sqrt(avg("squared_error")).alias("rmse")).collect()[0]["rmse"]
print(f"RMSE (ручной расчет): {rmse_manual:.4f}")
print(f"Время оценки: {time.time() - start_time:.2f} секунд")

print("\nСРАВНЕНИЕ МОДЕЛЕЙ")
print(f"Базовая модель (глобальное среднее):")
print(f"  RMSE = {rmse_base:.4f}")
print(f"ALS модель (коллаборативная фильтрация):")
print(f"  RMSE = {rmse_als:.4f}")
print(f"  Улучшение: {rmse_base - rmse_als:.4f} ({(rmse_base - rmse_als)/rmse_base*100:.2f}%)")
# Out:
# RMSE ALS модели: 0.8142
# RMSE (ручной расчет): 0.8142
# Время оценки: 65.18 секунд
#
# СРАВНЕНИЕ МОДЕЛЕЙ
# Базовая модель (глобальное среднее):
#   RMSE = 1.0641
# ALS модель (коллаборативная фильтрация):
#   RMSE = 0.8142
#   Улучшение: 0.2499 (23.49%)

# %%
ratings_df.unpersist()
als_train.unpersist()
als_test.unpersist()

spark.stop()
