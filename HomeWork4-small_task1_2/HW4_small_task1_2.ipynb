# %% [markdown]
# # ДОМАШНЕЕ ЗАДАНИЕ 4. Рекомендательные системы и Spark MLlib

# %% [markdown]
# **Дисциплина:** Методы обработки больших данных
# **Студент:** Попов Я.Ю.
# **Группа:** ИУ6-31М

# %% [markdown]
# ## Решение для малой выборки

# %% [markdown]
# ### Задание 1. Анализ датасета

# %% [markdown]
# 1. Выведите данные, сопоставляющие жанры и количество фильмов
# 2. Выведите первые 10 фильмов с наибольшим количеством рейтингов для каждого жанра в соответствии с вариантом
# 3. Выведите первые 10 фильмов с наименьшим количеством рейтингов (но больше 10) для каждого жанра в соответствии с вариантом
# 4. Выведите первые 10 фильмов с наибольшим средним рейтингом при количестве рейтингов больше 10 для каждого жанра в соответствии с вариантом
# 5. Выведите первые 10 фильмов с наименьшим средним рейтингом при количестве рейтингов больше 10 для каждого жанра в соответствии с вариантом

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, explode, split, count, avg, row_number
from pyspark.sql.window import Window

# Инициализация SparkSession
spark = SparkSession.builder \
    .appName("MovieRecommendationAnalysis") \
    .getOrCreate()

# Загрузка данных
movies_df = spark.read.csv("movies.csv", header=True, inferSchema=True)
ratings_df = spark.read.csv("ratings.csv", header=True, inferSchema=True)

# Список требуемых жанров
genres = [
    "Animation", "Romance", "Documentary", "Drama", 
    "Comedy", "Musical", "Thriller", "Sci-Fi", "Adventure"
]
# Out:
# /home/ubuntu/ML/anaconda3/lib/python3.7/site-packages/pyspark/context.py:317: FutureWarning: Python 3.7 support is deprecated in Spark 3.4.
#   warnings.warn("Python 3.7 support is deprecated in Spark 3.4.", FutureWarning)

# %% [markdown]
# ## Задача 1: Количество фильмов по жанрам

# %%
# Разделение на жанры по "|"
movies_exploded = movies_df.withColumn("genre", explode(split(col("genres"), "\\|")))
genre_counts = (
    movies_exploded
    .filter(col("genre").isin(genres))
    .groupBy("genre")
    .count()
    .orderBy(col("count").desc())
)

print("Задача 1: Количество фильмов по жанрам")
genre_counts.show()
# Out:
# Задача 1: Количество фильмов по жанрам
# +-----------+-----+
# |      genre|count|
# +-----------+-----+
# |      Drama| 4361|
# |     Comedy| 3756|
# |   Thriller| 1894|
# |    Romance| 1596|
# |  Adventure| 1263|
# |     Sci-Fi|  980|
# |  Animation|  611|
# |Documentary|  440|
# |    Musical|  334|
# +-----------+-----+

# %% [markdown]
# ## Задача 2: Топ-10 фильмов с наибольшим количеством рейтингов для каждого жанра

# %%
# Агрегация рейтингов
movie_ratings = (
    ratings_df
    .groupBy("movieId")
    .agg(
        count("rating").alias("rating_count"),
        avg("rating").alias("avg_rating")
    )
)

# Объединение с информацией о фильмах
movies_enriched = (
    movies_df
    .join(movie_ratings, "movieId", "inner")
    .withColumn("genre", explode(split(col("genres"), "\\|")))
    .filter(col("genre").isin(genres))
)


window_desc = Window.partitionBy("genre").orderBy(col("rating_count").desc())
top_by_count = (
    movies_enriched
    .withColumn("rank", row_number().over(window_desc))
    .filter(col("rank") <= 10)
    .select("genre", "title", "rating_count", "rank")
    .orderBy("genre", "rank")
)

print("\nЗадача 2: Топ-10 по количеству рейтингов")
top_by_count.show(n=100, truncate=False)
# Out:
# Задача 2: Топ-10 по количеству рейтингов
# +-----------+------------------------------------------------------------------------------+------------+----+
# |genre      |title                                                                         |rating_count|rank|
# +-----------+------------------------------------------------------------------------------+------------+----+
# |Adventure  |Star Wars: Episode IV - A New Hope (1977)                                     |251         |1   |
# |Adventure  |Jurassic Park (1993)                                                          |238         |2   |
# |Adventure  |Toy Story (1995)                                                              |215         |3   |
# |Adventure  |Star Wars: Episode V - The Empire Strikes Back (1980)                         |211         |4   |
# |Adventure  |Independence Day (a.k.a. ID4) (1996)                                          |202         |5   |
# |Adventure  |Apollo 13 (1995)                                                              |201         |6   |
# |Adventure  |Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)|200         |7   |
# |Adventure  |Lord of the Rings: The Fellowship of the Ring, The (2001)                     |198         |8   |
# |Adventure  |Star Wars: Episode VI - Return of the Jedi (1983)                             |196         |9   |
# |Adventure  |Lord of the Rings: The Two Towers, The (2002)                                 |188         |10  |
# |Animation  |Toy Story (1995)                                                              |215         |1   |
# |Animation  |Aladdin (1992)                                                                |183         |2   |
# |Animation  |Lion King, The (1994)                                                         |172         |3   |
# |Animation  |Shrek (2001)                                                                  |170         |4   |
# |Animation  |Beauty and the Beast (1991)                                                   |146         |5   |
# |Animation  |Finding Nemo (2003)                                                           |141         |6   |
# |Animation  |Monsters, Inc. (2001)                                                         |132         |7   |
# |Animation  |Incredibles, The (2004)                                                       |125         |8   |
# |Animation  |Up (2009)                                                                     |105         |9   |
# |Animation  |WALL·E (2008)                                                                 |104         |10  |
# |Comedy     |Forrest Gump (1994)                                                           |329         |1   |
# |Comedy     |Pulp Fiction (1994)                                                           |307         |2   |
# |Comedy     |Toy Story (1995)                                                              |215         |3   |
# |Comedy     |Aladdin (1992)                                                                |183         |4   |
# |Comedy     |Fargo (1996)                                                                  |181         |5   |
# |Comedy     |True Lies (1994)                                                              |178         |6   |
# |Comedy     |Back to the Future (1985)                                                     |171         |7   |
# |Comedy     |Shrek (2001)                                                                  |170         |8   |
# |Comedy     |Men in Black (a.k.a. MIB) (1997)                                              |165         |9   |
# |Comedy     |Ace Ventura: Pet Detective (1994)                                             |161         |10  |
# |Documentary|Bowling for Columbine (2002)                                                  |58          |1   |
# |Documentary|Super Size Me (2004)                                                          |50          |2   |
# |Documentary|Fahrenheit 9/11 (2004)                                                        |37          |3   |
# |Documentary|Roger & Me (1989)                                                             |31          |4   |
# |Documentary|Hoop Dreams (1994)                                                            |29          |5   |
# |Documentary|March of the Penguins (Marche de l'empereur, La) (2005)                       |18          |6   |
# |Documentary|Jackass: The Movie (2002)                                                     |17          |7   |
# |Documentary|Crumb (1994)                                                                  |17          |8   |
# |Documentary|Sicko (2007)                                                                  |14          |9   |
# |Documentary|Fog of War: Eleven Lessons from the Life of Robert S. McNamara, The (2003)    |13          |10  |
# |Drama      |Forrest Gump (1994)                                                           |329         |1   |
# |Drama      |Shawshank Redemption, The (1994)                                              |317         |2   |
# |Drama      |Pulp Fiction (1994)                                                           |307         |3   |
# |Drama      |Braveheart (1995)                                                             |237         |4   |
# |Drama      |Schindler's List (1993)                                                       |220         |5   |
# |Drama      |Fight Club (1999)                                                             |218         |6   |
# |Drama      |American Beauty (1999)                                                        |204         |7   |
# |Drama      |Apollo 13 (1995)                                                              |201         |8   |
# |Drama      |Godfather, The (1972)                                                         |192         |9   |
# |Drama      |Saving Private Ryan (1998)                                                    |188         |10  |
# |Musical    |Aladdin (1992)                                                                |183         |1   |
# |Musical    |Lion King, The (1994)                                                         |172         |2   |
# |Musical    |Beauty and the Beast (1991)                                                   |146         |3   |
# |Musical    |Willy Wonka & the Chocolate Factory (1971)                                    |119         |4   |
# |Musical    |Nightmare Before Christmas, The (1993)                                        |93          |5   |
# |Musical    |Wizard of Oz, The (1939)                                                      |92          |6   |
# |Musical    |Shrek 2 (2004)                                                                |92          |7   |
# |Musical    |Blues Brothers, The (1980)                                                    |84          |8   |
# |Musical    |Snow White and the Seven Dwarfs (1937)                                        |77          |9   |
# |Musical    |South Park: Bigger, Longer and Uncut (1999)                                   |76          |10  |
# |Romance    |Forrest Gump (1994)                                                           |329         |1   |
# |Romance    |American Beauty (1999)                                                        |204         |2   |
# |Romance    |True Lies (1994)                                                              |178         |3   |
# |Romance    |Speed (1994)                                                                  |171         |4   |
# |Romance    |Shrek (2001)                                                                  |170         |5   |
# |Romance    |Beauty and the Beast (1991)                                                   |146         |6   |
# |Romance    |Groundhog Day (1993)                                                          |143         |7   |
# |Romance    |Princess Bride, The (1987)                                                    |142         |8   |
# |Romance    |Good Will Hunting (1997)                                                      |141         |9   |
# |Romance    |Titanic (1997)                                                                |140         |10  |
# |Sci-Fi     |Matrix, The (1999)                                                            |278         |1   |
# |Sci-Fi     |Star Wars: Episode IV - A New Hope (1977)                                     |251         |2   |
# |Sci-Fi     |Jurassic Park (1993)                                                          |238         |3   |
# |Sci-Fi     |Terminator 2: Judgment Day (1991)                                             |224         |4   |
# |Sci-Fi     |Star Wars: Episode V - The Empire Strikes Back (1980)                         |211         |5   |
# |Sci-Fi     |Independence Day (a.k.a. ID4) (1996)                                          |202         |6   |
# |Sci-Fi     |Star Wars: Episode VI - Return of the Jedi (1983)                             |196         |7   |
# |Sci-Fi     |Twelve Monkeys (a.k.a. 12 Monkeys) (1995)                                     |177         |8   |
# |Sci-Fi     |Back to the Future (1985)                                                     |171         |9   |
# |Sci-Fi     |Men in Black (a.k.a. MIB) (1997)                                              |165         |10  |
# |Thriller   |Pulp Fiction (1994)                                                           |307         |1   |
# |Thriller   |Silence of the Lambs, The (1991)                                              |279         |2   |
# |Thriller   |Matrix, The (1999)                                                            |278         |3   |
# |Thriller   |Jurassic Park (1993)                                                          |238         |4   |
# |Thriller   |Fight Club (1999)                                                             |218         |5   |
# |Thriller   |Usual Suspects, The (1995)                                                    |204         |6   |
# |Thriller   |Seven (a.k.a. Se7en) (1995)                                                   |203         |7   |
# |Thriller   |Independence Day (a.k.a. ID4) (1996)                                          |202         |8   |
# |Thriller   |Fugitive, The (1993)                                                          |190         |9   |
# |Thriller   |Batman (1989)                                                                 |189         |10  |
# +-----------+------------------------------------------------------------------------------+------------+----+

# %% [markdown]
# ## Задача 3: Топ-10 фильмов с наименьшим количеством рейтингов (>10) для каждого жанра

# %%
window_asc = Window.partitionBy("genre").orderBy(col("rating_count").asc())
filtered_movies = movies_enriched.filter(col("rating_count") > 10)
bottom_by_count = (
    filtered_movies
    .withColumn("rank", row_number().over(window_asc))
    .filter(col("rank") <= 10)
    .select("genre", "title", "rating_count", "rank")
    .orderBy("genre", "rank")
)
print("\nЗадача 3: Наименьшее количество рейтингов (>10)")
bottom_by_count.show(truncate=False)
# Out:
# Задача 3: Наименьшее количество рейтингов (>10)
# +---------+--------------------------------------+------------+----+
# |genre    |title                                 |rating_count|rank|
# +---------+--------------------------------------+------------+----+
# |Adventure|Hidalgo (2004)                        |11          |1   |
# |Adventure|Young Sherlock Holmes (1985)          |11          |2   |
# |Adventure|Wild Bunch, The (1969)                |11          |3   |
# |Adventure|Bulletproof Monk (2003)               |11          |4   |
# |Adventure|All Dogs Go to Heaven 2 (1996)        |11          |5   |
# |Adventure|Edge, The (1997)                      |11          |6   |
# |Adventure|Oliver & Company (1988)               |11          |7   |
# |Adventure|Medicine Man (1992)                   |11          |8   |
# |Adventure|Avengers, The (1998)                  |11          |9   |
# |Adventure|Chitty Chitty Bang Bang (1968)        |11          |10  |
# |Animation|How the Grinch Stole Christmas! (1966)|11          |1   |
# |Animation|All Dogs Go to Heaven 2 (1996)        |11          |2   |
# |Animation|Persepolis (2007)                     |11          |3   |
# |Animation|Oliver & Company (1988)               |11          |4   |
# |Animation|Polar Express, The (2004)             |11          |5   |
# |Animation|Meet the Robinsons (2007)             |11          |6   |
# |Animation|Happy Feet (2006)                     |11          |7   |
# |Animation|Ponyo (Gake no ue no Ponyo) (2008)    |11          |8   |
# |Animation|Hotel Transylvania (2012)             |11          |9   |
# |Animation|Rise of the Guardians (2012)          |12          |10  |
# +---------+--------------------------------------+------------+----+
# only showing top 20 rows

# %% [markdown]
# ## Задача 4: Топ-10 фильмов с наибольшим средним рейтингом (>10 рейтингов)

# %%
window_avg_desc = Window.partitionBy("genre").orderBy(
    col("avg_rating").desc(),
    col("rating_count").desc()
)
top_by_avg = (
    filtered_movies
    .withColumn("rank", row_number().over(window_avg_desc))
    .filter(col("rank") <= 10)
    .select("genre", "title", "avg_rating", "rating_count", "rank")
    .orderBy("genre", "rank")
)
print("\nЗадача 4: Наивысший средний рейтинг (>10)")
top_by_avg.show(truncate=False)
# Out:
# Задача 4: Наивысший средний рейтинг (>10)
# +---------+------------------------------------------------------------------------------+------------------+------------+----+
# |genre    |title                                                                         |avg_rating        |rating_count|rank|
# +---------+------------------------------------------------------------------------------+------------------+------------+----+
# |Adventure|Lawrence of Arabia (1962)                                                     |4.3               |45          |1   |
# |Adventure|Outlaw Josey Wales, The (1976)                                                |4.25              |18          |2   |
# |Adventure|Princess Bride, The (1987)                                                    |4.232394366197183 |142         |3   |
# |Adventure|Star Wars: Episode IV - A New Hope (1977)                                     |4.231075697211155 |251         |4   |
# |Adventure|Yojimbo (1961)                                                                |4.230769230769231 |13          |5   |
# |Adventure|Star Wars: Episode V - The Empire Strikes Back (1980)                         |4.2156398104265405|211         |6   |
# |Adventure|Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)|4.2075            |200         |7   |
# |Adventure|Seven Samurai (Shichinin no samurai) (1954)                                   |4.1875            |48          |8   |
# |Adventure|North by Northwest (1959)                                                     |4.184210526315789 |57          |9   |
# |Adventure|Monty Python and the Holy Grail (1975)                                        |4.161764705882353 |136         |10  |
# |Animation|Creature Comforts (1989)                                                      |4.25              |12          |1   |
# |Animation|Persepolis (2007)                                                             |4.181818181818182 |11          |2   |
# |Animation|Grave of the Fireflies (Hotaru no haka) (1988)                                |4.15625           |16          |3   |
# |Animation|Spirited Away (Sen to Chihiro no kamikakushi) (2001)                          |4.155172413793103 |87          |4   |
# |Animation|Ghost in the Shell (Kôkaku kidôtai) (1995)                                    |4.148148148148148 |27          |5   |
# |Animation|Batman: Mask of the Phantasm (1993)                                           |4.115384615384615 |13          |6   |
# |Animation|Toy Story 3 (2010)                                                            |4.109090909090909 |55          |7   |
# |Animation|Wallace & Gromit: The Best of Aardman Animation (1996)                        |4.092592592592593 |27          |8   |
# |Animation|Grand Day Out with Wallace and Gromit, A (1989)                               |4.089285714285714 |28          |9   |
# |Animation|Fantastic Mr. Fox (2009)                                                      |4.083333333333333 |18          |10  |
# +---------+------------------------------------------------------------------------------+------------------+------------+----+
# only showing top 20 rows

# %% [markdown]
# ## Задача 5: Топ-10 фильмов с наименьшим средним рейтингом (>10 рейтингов)

# %%
window_avg_asc = Window.partitionBy("genre").orderBy(
    col("avg_rating").asc(),
    col("rating_count").desc()
)
bottom_by_avg = (
    filtered_movies
    .withColumn("rank", row_number().over(window_avg_asc))
    .filter(col("rank") <= 10)
    .select("genre", "title", "avg_rating", "rating_count", "rank")
    .orderBy("genre", "rank")
)
print("\nЗадача 5: Наименьший средний рейтинг (>10)")
bottom_by_avg.show(n=100, truncate=False)
# Out:
# Задача 5: Наименьший средний рейтинг (>10)
# +-----------+---------------------------------------------------------------------------+------------------+------------+----+
# |genre      |title                                                                      |avg_rating        |rating_count|rank|
# +-----------+---------------------------------------------------------------------------+------------------+------------+----+
# |Adventure  |Superman IV: The Quest for Peace (1987)                                    |1.6875            |16          |1   |
# |Adventure  |Karate Kid, Part III, The (1989)                                           |1.75              |14          |2   |
# |Adventure  |Dungeons & Dragons (2000)                                                  |1.8333333333333333|12          |3   |
# |Adventure  |Rambo III (1988)                                                           |1.9166666666666667|12          |4   |
# |Adventure  |Anaconda (1997)                                                            |1.9259259259259258|27          |5   |
# |Adventure  |Super Mario Bros. (1993)                                                   |2.0               |21          |6   |
# |Adventure  |Teenage Mutant Ninja Turtles III (1993)                                    |2.0714285714285716|14          |7   |
# |Adventure  |Dukes of Hazzard, The (2005)                                               |2.0833333333333335|12          |8   |
# |Adventure  |Inspector Gadget (1999)                                                    |2.0952380952380953|21          |9   |
# |Adventure  |Howard the Duck (1986)                                                     |2.15625           |16          |10  |
# |Animation  |Shark Tale (2004)                                                          |2.3461538461538463|13          |1   |
# |Animation  |Ice Age: Dawn of the Dinosaurs (2009)                                      |2.607142857142857 |14          |2   |
# |Animation  |Happy Feet (2006)                                                          |2.6818181818181817|11          |3   |
# |Animation  |All Dogs Go to Heaven (1989)                                               |2.7               |15          |4   |
# |Animation  |Space Jam (1996)                                                           |2.707547169811321 |53          |5   |
# |Animation  |Pete's Dragon (1977)                                                       |2.7666666666666666|15          |6   |
# |Animation  |Small Soldiers (1998)                                                      |2.8333333333333335|18          |7   |
# |Animation  |Beavis and Butt-Head Do America (1996)                                     |2.935483870967742 |31          |8   |
# |Animation  |Goofy Movie, A (1995)                                                      |3.0               |17          |9   |
# |Animation  |Shrek the Third (2007)                                                     |3.0238095238095237|21          |10  |
# |Comedy     |Problem Child (1990)                                                       |1.5833333333333333|12          |1   |
# |Comedy     |Flintstones in Viva Rock Vegas, The (2000)                                 |1.625             |12          |2   |
# |Comedy     |Beethoven (1992)                                                           |1.7727272727272727|11          |3   |
# |Comedy     |Stop! Or My Mom Will Shoot (1992)                                          |1.7727272727272727|11          |4   |
# |Comedy     |Dungeons & Dragons (2000)                                                  |1.8333333333333333|12          |5   |
# |Comedy     |Sister Act 2: Back in the Habit (1993)                                     |1.8928571428571428|14          |6   |
# |Comedy     |Dumb and Dumberer: When Harry Met Lloyd (2003)                             |1.9545454545454546|11          |7   |
# |Comedy     |Super Mario Bros. (1993)                                                   |2.0               |21          |8   |
# |Comedy     |Honey, I Blew Up the Kid (1992)                                            |2.05              |20          |9   |
# |Comedy     |Teenage Mutant Ninja Turtles III (1993)                                    |2.0714285714285716|14          |10  |
# |Documentary|Fahrenheit 9/11 (2004)                                                     |3.4864864864864864|37          |1   |
# |Documentary|Jackass: The Movie (2002)                                                  |3.5               |17          |2   |
# |Documentary|Super Size Me (2004)                                                       |3.51              |50          |3   |
# |Documentary|March of the Penguins (Marche de l'empereur, La) (2005)                    |3.5555555555555554|18          |4   |
# |Documentary|Inconvenient Truth, An (2006)                                              |3.576923076923077 |13          |5   |
# |Documentary|Sicko (2007)                                                               |3.7142857142857144|14          |6   |
# |Documentary|Bowling for Columbine (2002)                                               |3.7758620689655173|58          |7   |
# |Documentary|Roger & Me (1989)                                                          |3.838709677419355 |31          |8   |
# |Documentary|Koyaanisqatsi (a.k.a. Koyaanisqatsi: Life Out of Balance) (1983)           |3.8636363636363638|11          |9   |
# |Documentary|King of Kong, The (2007)                                                   |3.9166666666666665|12          |10  |
# |Drama      |Karate Kid, Part III, The (1989)                                           |1.75              |14          |1   |
# |Drama      |Beethoven (1992)                                                           |1.7727272727272727|11          |2   |
# |Drama      |Rocky V (1990)                                                             |1.9411764705882353|17          |3   |
# |Drama      |Fast and the Furious: Tokyo Drift, The (Fast and the Furious 3, The) (2006)|2.090909090909091 |11          |4   |
# |Drama      |Volcano (1997)                                                             |2.1               |15          |5   |
# |Drama      |Crocodile Dundee in Los Angeles (2001)                                     |2.1923076923076925|13          |6   |
# |Drama      |Clash of the Titans (2010)                                                 |2.3076923076923075|13          |7   |
# |Drama      |Free Willy (1993)                                                          |2.391891891891892 |37          |8   |
# |Drama      |RoboCop 3 (1993)                                                           |2.4047619047619047|21          |9   |
# |Drama      |Twilight (2008)                                                            |2.409090909090909 |22          |10  |
# |Musical    |Grease 2 (1982)                                                            |2.0789473684210527|19          |1   |
# |Musical    |Popeye (1980)                                                              |2.5               |18          |2   |
# |Musical    |Blues Brothers 2000 (1998)                                                 |2.7083333333333335|12          |3   |
# |Musical    |Pete's Dragon (1977)                                                       |2.7666666666666666|15          |4   |
# |Musical    |Mamma Mia! (2008)                                                          |2.9642857142857144|14          |5   |
# |Musical    |Oliver & Company (1988)                                                    |3.090909090909091 |11          |6   |
# |Musical    |Annie (1982)                                                               |3.125             |16          |7   |
# |Musical    |Grease (1978)                                                              |3.139705882352941 |68          |8   |
# |Musical    |Pocahontas (1995)                                                          |3.1470588235294117|68          |9   |
# |Musical    |Aladdin and the King of Thieves (1996)                                     |3.1538461538461537|13          |10  |
# |Romance    |Speed 2: Cruise Control (1997)                                             |1.605263157894737 |19          |1   |
# |Romance    |Grease 2 (1982)                                                            |2.0789473684210527|19          |2   |
# |Romance    |Bewitched (2005)                                                           |2.269230769230769 |13          |3   |
# |Romance    |Next Karate Kid, The (1994)                                                |2.3666666666666667|15          |4   |
# |Romance    |Joe Dirt (2001)                                                            |2.380952380952381 |21          |5   |
# |Romance    |Look Who's Talking (1989)                                                  |2.388888888888889 |18          |6   |
# |Romance    |Twilight (2008)                                                            |2.409090909090909 |22          |7   |
# |Romance    |Autumn in New York (2000)                                                  |2.409090909090909 |11          |8   |
# |Romance    |Sex and the City (2008)                                                    |2.409090909090909 |11          |9   |
# |Romance    |Down to Earth (2001)                                                       |2.4166666666666665|12          |10  |
# |Sci-Fi     |Battlefield Earth (2000)                                                   |1.6578947368421053|19          |1   |
# |Sci-Fi     |Superman IV: The Quest for Peace (1987)                                    |1.6875            |16          |2   |
# |Sci-Fi     |Ultraviolet (2006)                                                         |1.9230769230769231|13          |3   |
# |Sci-Fi     |Godzilla (1998)                                                            |1.9545454545454546|33          |4   |
# |Sci-Fi     |Super Mario Bros. (1993)                                                   |2.0               |21          |5   |
# |Sci-Fi     |Honey, I Blew Up the Kid (1992)                                            |2.05              |20          |6   |
# |Sci-Fi     |Howard the Duck (1986)                                                     |2.15625           |16          |7   |
# |Sci-Fi     |Universal Soldier (1992)                                                   |2.2058823529411766|17          |8   |
# |Sci-Fi     |Wild Wild West (1999)                                                      |2.207547169811321 |53          |9   |
# |Sci-Fi     |Superman III (1983)                                                        |2.25              |22          |10  |
# |Thriller   |Speed 2: Cruise Control (1997)                                             |1.605263157894737 |19          |1   |
# |Thriller   |Rambo III (1988)                                                           |1.9166666666666667|12          |2   |
# |Thriller   |Ultraviolet (2006)                                                         |1.9230769230769231|13          |3   |
# |Thriller   |Anaconda (1997)                                                            |1.9259259259259258|27          |4   |
# |Thriller   |Godzilla (1998)                                                            |1.9545454545454546|33          |5   |
# |Thriller   |I Still Know What You Did Last Summer (1998)                               |2.0555555555555554|18          |6   |
# |Thriller   |Fast and the Furious: Tokyo Drift, The (Fast and the Furious 3, The) (2006)|2.090909090909091 |11          |7   |
# |Thriller   |Volcano (1997)                                                             |2.1               |15          |8   |
# |Thriller   |I Know What You Did Last Summer (1997)                                     |2.109375          |32          |9   |
# |Thriller   |Haunting, The (1999)                                                       |2.1153846153846154|13          |10  |
# +-----------+---------------------------------------------------------------------------+------------------+------------+----+

# %% [markdown]
# # Остановка SparkSession

# %%
spark.stop()

# %% [markdown]
# ### Задание 2. Коллаборативная фильтрация

# %% [markdown]
# Вариант 1. По схожести пользователей
#
# Вариант 2. По схожести объектов
#
# 1. Разделите данные с рейтингами на обучающее (train_init - 0.8) и тестовое подмножества (test - 0.2), определите среднее значение рейтинга в обучающем подмножестве и вычислите rmse для тестового подмножества, если для всех значений из test предсказывается среднее значение рейтинга
# 2. Реализуйте коллаборативную фильтрацию в соответствии с вариантом. Для определения схожести используйте train_init, для расчета rmse - test
# 3. Определите rmse для тестового подмножества

# %%
surname = "Попов" 

alp = 'абвгдеёжзийклмнопрстуфхцчшщъыьэюя'
w = [1, 42, 21, 21, 34,  6, 44, 26, 18, 44, 38, 26, 14, 43,  4, 49, 45,
        7, 42, 29,  4,  9, 36, 34, 31, 29,  5, 30,  4, 19, 28, 25, 33]

d = dict(zip(alp, w))
variant =  sum([d[el] for el in surname.lower()]) % 40 + 1

print("Задача № 2: ", variant % 2 + 1 )
# Out:
# Задача № 2:  1

# %% [markdown]
# ## Инициализация SparkSession

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, broadcast, avg, lit, sqrt
from pyspark.ml.recommendation import ALS
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.sql.window import Window
import time

spark = SparkSession.builder \
    .appName("CollaborativeFiltering") \
    .config("spark.driver.memory", "4g") \
    .config("spark.sql.shuffle.partitions", "8") \
    .getOrCreate()

ratings_df = spark.read.csv("ratings.csv", header=True, inferSchema=True)
# Out:
# /home/ubuntu/ML/anaconda3/lib/python3.7/site-packages/pyspark/context.py:317: FutureWarning: Python 3.7 support is deprecated in Spark 3.4.
#   warnings.warn("Python 3.7 support is deprecated in Spark 3.4.", FutureWarning)

# %% [markdown]
# ## 1: Разделение данных и вычисление RMSE для среднего значения

# %%
# Разделение данных
train_init, test = ratings_df.randomSplit([0.8, 0.2], seed=42)

# Вычисление среднего рейтинга в обучающей выборке
avg_rating = train_init.agg(avg("rating").alias("avg_rating")).collect()[0]["avg_rating"]
print(f"Средний рейтинг в обучающей выборке: {avg_rating:.4f}")

test_with_pred = test.withColumn("prediction", lit(avg_rating))

# Расчет RMSE вручную
rmse_base = test_with_pred.withColumn("squared_error", (col("rating") - col("prediction"))**2)
rmse_base = rmse_base.agg(sqrt(avg("squared_error")).alias("rmse")).collect()[0]["rmse"]
print(f"RMSE базовой модели (предсказание средним): {rmse_base:.4f}")
# Out:
# Средний рейтинг в обучающей выборке: 3.5039
# RMSE базовой модели (предсказание средним): 1.0504

# %% [markdown]
# ## 2: Реализация коллаборативной фильтрации по схожести пользователей

# %%
# Подготовка данных для ALS
als_train = train_init.select(
    col("userId").cast("integer").alias("user"),
    col("movieId").cast("integer").alias("item"),
    col("rating").cast("float")
)

als_test = test.select(
    col("userId").cast("integer").alias("user"),
    col("movieId").cast("integer").alias("item"),
    col("rating").cast("float")
)

# Обучение ALS модели
als = ALS(
    maxIter=5,
    regParam=0.01,
    userCol="user",
    itemCol="item",
    ratingCol="rating",
    coldStartStrategy="drop",
    seed=42
)

start_time = time.time()
model = als.fit(als_train)
print(f"Модель обучена за {time.time() - start_time:.2f} секунд")

predictions = model.transform(als_test)
# Out:
# Модель обучена за 6.84 секунд

# %% [markdown]
# ## 3: Определение RMSE для тестового подмножества

# %%
# Расчет RMSE с использованием RegressionEvaluator
evaluator = RegressionEvaluator(
    metricName="rmse",
    labelCol="rating",
    predictionCol="prediction"
)

rmse_als = evaluator.evaluate(predictions)
print(f"RMSE ALS модели: {rmse_als:.4f}")

# Альтернативный расчет RMSE вручную
rmse_manual = predictions.withColumn("squared_error", (col("rating") - col("prediction"))**2)
rmse_manual = rmse_manual.agg(sqrt(avg("squared_error")).alias("rmse")).collect()[0]["rmse"]
print(f"RMSE (ручной расчет): {rmse_manual:.4f}")

# Сравнение результатов
print("\nСравнение моделей:")
print(f"Базовая модель (среднее): RMSE = {rmse_base:.4f}")
print(f"ALS модель:              RMSE = {rmse_als:.4f}")
print(f"Улучшение:               {rmse_base - rmse_als:.4f}")

# Дополнительная информация о модели
print("\nХарактеристики модели:")
print(f"Число пользователей в обучении: {model.userFactors.count()}")
print(f"Число фильмов в обучении:      {model.itemFactors.count()}")
print(f"Размерность векторов:          {len(model.userFactors.first()['features'])}")
# Out:
# RMSE ALS модели: 1.0943
# RMSE (ручной расчет): 1.0943
#
# Сравнение моделей:
# Базовая модель (среднее): RMSE = 1.0504
# ALS модель:              RMSE = 1.0943
# Улучшение:               -0.0438
#
# Характеристики модели:
# Число пользователей в обучении: 610
# Число фильмов в обучении:      8954
# Размерность векторов:          10

# %% [markdown]
# ## Остановка SparkSession

# %%
spark.stop()
